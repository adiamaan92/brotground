# %%
# !pip install brotground==0.1.3

# %%
from brotground import MandelBrot, MultiBrot, UserBrot 
from brotground.resources import burning_ship_brot_equation, tricorn_brot_equation, StaticRenderer

# %%
matplot_renderer = StaticRenderer()

# %%
# %%time
mandel = MandelBrot()
# Out:
# Wall time: 1.91 ms

# %%
# %%time
mandel.iterate_diverge(max_iterations=25)
matplot_renderer.plot(mandel, cmap="RdGy")
# Out:
# Wall time: 856 ms

# %%
mandel.set_boundaries((-0.02, 0.02), (0.780, 0.820))
mandel.iterate_diverge(max_iterations=100)
matplot_renderer.plot(mandel, cmap="plasma")

# %%
# %%time
multi = MultiBrot()

multi.iterate_diverge(max_iterations=15)
matplot_renderer.plot(multi, cmap="binary")
# Out:
# Wall time: 992 ms

# %%
# %%time
tricorn = UserBrot(brot_equation=tricorn_brot_equation)
# Out:
# Wall time: 1.79 ms

# %%
# %%time
tricorn.iterate_diverge(max_iterations=15)
matplot_renderer.plot(tricorn, cmap="RdYlBu")
# Out:
# Wall time: 66.9 ms

# %%
# %%time
burning_ship = UserBrot(brot_equation=burning_ship_brot_equation)
# Out:
# Wall time: 1 ms

# %%
# %%time
burning_ship.iterate_diverge(max_iterations=15)
matplot_renderer.plot(burning_ship, cmap="copper")
# Out:
# Wall time: 943 ms
